# %% [markdown]
# # Project 3
#
# #### Importing Packages and Loading the Data

# %%
import datetime
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("Iowa_Liquor_sales_sample_10pct.csv")
df.head()
# Out:
#          Date  Store Number         City Zip Code  County Number      County  \
# 0  11/04/2015          3717       SUMNER    50674            9.0      Bremer
# 1  03/02/2016          2614    DAVENPORT    52807           82.0       Scott
# 2  02/11/2016          2106  CEDAR FALLS    50613            7.0  Black Hawk
# 3  02/03/2016          2501         AMES    50010           85.0       Story
# 4  08/18/2015          3654      BELMOND    50421           99.0      Wright
#
#     Category              Category Name  Vendor Number  Item Number  \
# 0  1051100.0           APRICOT BRANDIES             55        54436
# 1  1011100.0           BLENDED WHISKIES            395        27605
# 2  1011200.0  STRAIGHT BOURBON WHISKIES             65        19067
# 3  1071100.0         AMERICAN COCKTAILS            395        59154
# 4  1031080.0             VODKA 80 PROOF            297        35918
#
#             Item Description  Bottle Volume (ml) State Bottle Cost  \
# 0  Mr. Boston Apricot Brandy                 750             $4.50
# 1                    Tin Cup                 750            $13.75
# 2                   Jim Beam                1000            $12.59
# 3    1800 Ultimate Margarita                1750             $9.50
# 4         Five O'clock Vodka                1750             $7.20
#
#   State Bottle Retail  Bottles Sold Sale (Dollars)  Volume Sold (Liters)  \
# 0               $6.75            12         $81.00                   9.0
# 1              $20.63             2         $41.26                   1.5
# 2              $18.89            24        $453.36                  24.0
# 3              $14.25             6         $85.50                  10.5
# 4              $10.80            12        $129.60                  21.0
#
#    Volume Sold (Gallons)
# 0                   2.38
# 1                   0.40
# 2                   6.34
# 3                   2.77
# 4                   5.55

# %%
df.shape
# Out:
# (270955, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270955 entries, 0 to 270954
# Data columns (total 18 columns):
# Date                     270955 non-null object
# Store Number             270955 non-null int64
# City                     270955 non-null object
# Zip Code                 270955 non-null object
# County Number            269878 non-null float64
# County                   269878 non-null object
# Category                 270887 non-null float64
# Category Name            270323 non-null object
# Vendor Number            270955 non-null int64
# Item Number              270955 non-null int64
# Item Description         270955 non-null object
# Bottle Volume (ml)       270955 non-null int64
# State Bottle Cost        270955 non-null object
# State Bottle Retail      270955 non-null object
# Bottles Sold             270955 non-null int64
# Sale (Dollars)           270955 non-null object
# Volume Sold (Liters)     270955 non-null float64
# Volume Sold (Gallons)    270955 non-null float64
# dtypes: float64(4), int64(5), object(9)
# memory usage: 37.2+ MB

# %% [markdown]
# ## Cleaning the data
#
# Task List:
# * Remove "$" prices from characters and convert values to floats.
# * Convert dates to pandas datetime objects
# * Convert category floats to integers
# * Drop or fill in bad values

# %% [markdown]
# ##### Remove "$" prices from characters and convert values to floats

# %%
dollar_removal_cols = ["State Bottle Cost", "State Bottle Retail", "Sale (Dollars)"]

for col in dollar_removal_cols:
    df[col] = df[col].apply(lambda x: float(x[1:]))

# %%
df.head(2)
# Out:
#          Date  Store Number       City Zip Code  County Number  County  \
# 0  11/04/2015          3717     SUMNER    50674            9.0  Bremer
# 1  03/02/2016          2614  DAVENPORT    52807           82.0   Scott
#
#     Category     Category Name  Vendor Number  Item Number  \
# 0  1051100.0  APRICOT BRANDIES             55        54436
# 1  1011100.0  BLENDED WHISKIES            395        27605
#
#             Item Description  Bottle Volume (ml)  State Bottle Cost  \
# 0  Mr. Boston Apricot Brandy                 750               4.50
# 1                    Tin Cup                 750              13.75
#
#    State Bottle Retail  Bottles Sold  Sale (Dollars)  Volume Sold (Liters)  \
# 0                 6.75            12           81.00                   9.0
# 1                20.63             2           41.26                   1.5
#
#    Volume Sold (Gallons)
# 0                   2.38
# 1                   0.40

# %% [markdown]
# ##### Convert dates to pandas datetime objects

# %%
df["Date"] = pd.to_datetime(df["Date"], format="%m/%d/%Y")
df.head(2)
# Out:
#         Date  Store Number       City Zip Code  County Number  County  \
# 0 2015-11-04          3717     SUMNER    50674            9.0  Bremer
# 1 2016-03-02          2614  DAVENPORT    52807           82.0   Scott
#
#     Category     Category Name  Vendor Number  Item Number  \
# 0  1051100.0  APRICOT BRANDIES             55        54436
# 1  1011100.0  BLENDED WHISKIES            395        27605
#
#             Item Description  Bottle Volume (ml)  State Bottle Cost  \
# 0  Mr. Boston Apricot Brandy                 750               4.50
# 1                    Tin Cup                 750              13.75
#
#    State Bottle Retail  Bottles Sold  Sale (Dollars)  Volume Sold (Liters)  \
# 0                 6.75            12           81.00                   9.0
# 1                20.63             2           41.26                   1.5
#
#    Volume Sold (Gallons)
# 0                   2.38
# 1                   0.40

# %%
df["Date"].max()
# Out:
# Timestamp('2016-03-31 00:00:00')

# %%
df["Date"].min()
# Out:
# Timestamp('2015-01-05 00:00:00')

# %% [markdown]
# ##### Drop or replace 'bad' values

# %%
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 269258 entries, 0 to 270954
# Data columns (total 18 columns):
# Date                     269258 non-null datetime64[ns]
# Store Number             269258 non-null int64
# City                     269258 non-null object
# Zip Code                 269258 non-null object
# County Number            269258 non-null float64
# County                   269258 non-null object
# Category                 269258 non-null float64
# Category Name            269258 non-null object
# Vendor Number            269258 non-null int64
# Item Number              269258 non-null int64
# Item Description         269258 non-null object
# Bottle Volume (ml)       269258 non-null int64
# State Bottle Cost        269258 non-null float64
# State Bottle Retail      269258 non-null float64
# Bottles Sold             269258 non-null int64
# Sale (Dollars)           269258 non-null float64
# Volume Sold (Liters)     269258 non-null float64
# Volume Sold (Gallons)    269258 non-null float64
# dtypes: datetime64[ns](1), float64(7), int64(5), object(5)
# memory usage: 39.0+ MB

# %% [markdown]
# ##### Convert category floats to integers

# %%
df["County Number"] = df["County Number"].astype(int)
df["Category"] = df["Category"].astype(int)
df.head(2)
# Out:
#         Date  Store Number       City Zip Code  County Number  County  \
# 0 2015-11-04          3717     SUMNER    50674              9  Bremer
# 1 2016-03-02          2614  DAVENPORT    52807             82   Scott
#
#    Category     Category Name  Vendor Number  Item Number  \
# 0   1051100  APRICOT BRANDIES             55        54436
# 1   1011100  BLENDED WHISKIES            395        27605
#
#             Item Description  Bottle Volume (ml)  State Bottle Cost  \
# 0  Mr. Boston Apricot Brandy                 750               4.50
# 1                    Tin Cup                 750              13.75
#
#    State Bottle Retail  Bottles Sold  Sale (Dollars)  Volume Sold (Liters)  \
# 0                 6.75            12           81.00                   9.0
# 1                20.63             2           41.26                   1.5
#
#    Volume Sold (Gallons)
# 0                   2.38
# 1                   0.40

# %% [markdown]
# ## Filter the Data
#
# Some stores may have opened or closed in 2015. These data points will heavily skew our models, so we need to filter them out or find a way to deal with them.
#
# You'll need to provide a summary in your project report about these data points. You may also consider using the monthly sales in your model and including other information (number of months or days each store is open) in your data to handle these unusual cases.
#
# Let's record the first and last sales dates for each store. We'll save this information for later when we fit our models.
#
# ##### Determine which stores were open all of 2015 - finding the first and last sale date

# %%
dates = df.groupby(by=["Store Number"], as_index=False)
dates = dates.agg({"Date": [np.min, np.max]})

# %% [markdown]
# ##### For formatting purposes, this strips the empty cell above the first row

# %%
dates.columns = [' '.join(col).strip() for col in dates.columns.values]
dates.head()
# Out:
#    Store Number  Date amin  Date amax
# 0          2106 2015-01-08 2016-03-31
# 1          2113 2015-01-07 2016-03-23
# 2          2130 2015-01-08 2016-03-31
# 3          2152 2015-01-08 2016-02-25
# 4          2178 2015-01-07 2016-03-30

# %% [markdown]
# ##### This code filters out stores that opened or closed during 2015 using a mask
#
# Stores that opened after March 1st and stores that closed before October 1 are to be considered partial year stores

# %%
lower_cutoff = pd.Timestamp("20150301")
upper_cutoff = pd.Timestamp("20151001")

mask = (dates['Date amin'] < lower_cutoff) & (dates['Date amax'] > upper_cutoff)

good_stores = dates[mask]["Store Number"]

good_stores_df = df[df["Store Number"].isin(good_stores)]
# saving this mask for later per John's suggestion

# %%
good_stores_df.head()
# Out:
#         Date  Store Number         City Zip Code  County Number      County  \
# 0 2015-11-04          3717       SUMNER    50674              9      Bremer
# 1 2016-03-02          2614    DAVENPORT    52807             82       Scott
# 2 2016-02-11          2106  CEDAR FALLS    50613              7  Black Hawk
# 3 2016-02-03          2501         AMES    50010             85       Story
# 4 2015-08-18          3654      BELMOND    50421             99      Wright
#
#    Category              Category Name  Vendor Number  Item Number  \
# 0   1051100           APRICOT BRANDIES             55        54436
# 1   1011100           BLENDED WHISKIES            395        27605
# 2   1011200  STRAIGHT BOURBON WHISKIES             65        19067
# 3   1071100         AMERICAN COCKTAILS            395        59154
# 4   1031080             VODKA 80 PROOF            297        35918
#
#             Item Description  Bottle Volume (ml)  State Bottle Cost  \
# 0  Mr. Boston Apricot Brandy                 750               4.50
# 1                    Tin Cup                 750              13.75
# 2                   Jim Beam                1000              12.59
# 3    1800 Ultimate Margarita                1750               9.50
# 4         Five O'clock Vodka                1750               7.20
#
#    State Bottle Retail  Bottles Sold  Sale (Dollars)  Volume Sold (Liters)  \
# 0                 6.75            12           81.00                   9.0
# 1                20.63             2           41.26                   1.5
# 2                18.89            24          453.36                  24.0
# 3                14.25             6           85.50                  10.5
# 4                10.80            12          129.60                  21.0
#
#    Volume Sold (Gallons)
# 0                   2.38
# 1                   0.40
# 2                   6.34
# 3                   2.77
# 4                   5.55

# %%
good_stores_df.shape
# Out:
# (256181, 18)

# %%
df.shape
# Out:
# (269258, 18)

# %% [markdown]
# ## Computing New Columns and Tables
#
# Since we're trying to predict sales and/or profits, we'll want to compute some intermediate data. There are a lot of ways to do this and good use of pandas is crucial. For example, for each transaction we may want to know:
# * unit margin, retail cost minus bottle cost
# * gross margin - gross margin * bottles sold
# * price per bottle
# * price per liter
#
# We'll need to make a new dataframe that indexes quantities by store:
# * sales per store for all of 2015
# * sales per store for Q1 2015
# * sales per store for Q1 2016
# * total volumes sold
# * mean transaction revenue, gross margin, price per bottle, price per liter, etc.
# * average sales per day
# * number of days open (count of sales per store)
#
# Make sure to retain other variables that we'll want to use to build our models, such as zip code, county number, city, etc. We recommend that you spend some time thinking about the model you may want to fit and computing enough of the suggested quantities to give you a few options.
#
# Bonus tasks:
# * Restrict your attention to stores that were open for all of 2015 and Q1 2016. Stores that opened or closed in 2015 will introduce outliers into your data.
# * For each transaction we have the item category. You may be able to determine the store type (primarily wine, liquor, all types of alcohol, etc.) by the most common transaction category for each store. This could be a useful categorical variable for modelling.

# %% [markdown]
# ##### Calculating Unit Margin

# %%
df["Unit_Margin"] = (df["State Bottle Retail"] - df["State Bottle Cost"])

# %% [markdown]
# ##### Calculating Gross Margin

# %%
df["Gross_Margin"] = (df["State Bottle Retail"] - df["State Bottle Cost"]) * df["Bottles Sold"]

# %% [markdown]
# ##### Revenue per Liter

# %%
df["Revenue_per_Liter"] = df["Sale (Dollars)"] / df["Volume Sold (Liters)"]

# %% [markdown]
# ##### Gross Margin per Liter

# %%
df["Gross_Margin_per_Liter"] = ((df["State Bottle Retail"] - df["State Bottle Cost"]) 
                                * df["Bottles Sold"]) / df["Volume Sold (Liters)"]

# %% [markdown]
# Checking our DataFrame after new column additions

# %%
df.head(2)
# Out:
#         Date  Store Number       City Zip Code  County Number  County  \
# 0 2015-11-04          3717     SUMNER    50674              9  Bremer
# 1 2016-03-02          2614  DAVENPORT    52807             82   Scott
#
#    Category     Category Name  Vendor Number  Item Number  \
# 0   1051100  APRICOT BRANDIES             55        54436
# 1   1011100  BLENDED WHISKIES            395        27605
#
#             ...           State Bottle Cost  State Bottle Retail  \
# 0           ...                        4.50                 6.75
# 1           ...                       13.75                20.63
#
#    Bottles Sold  Sale (Dollars)  Volume Sold (Liters)  Volume Sold (Gallons)  \
# 0            12           81.00                   9.0                   2.38
# 1             2           41.26                   1.5                   0.40
#
#    Unit_Margin  Gross_Margin  Revenue_per_Liter  Gross_Margin_per_Liter
# 0         2.25         27.00           9.000000                3.000000
# 1         6.88         13.76          27.506667                9.173333
#
# [2 rows x 22 columns]

# %% [markdown]
# ##### Calculating Sales per Store for 2015

# %% [markdown]
# Step 1 - Filtering by start and end dates (January 1, 2015 and December 31, 2015, respectively)

# %%
df.sort_values(by=["Store Number", "Date"], inplace=True)

start_date = pd.Timestamp("20150101")
end_date = pd.Timestamp("20151231")

sales_mask_2015 = (df['Date'] >= start_date) & (df['Date'] <= end_date)
sales_2015_df = df[sales_mask_2015]

# %% [markdown]
# Step 2 - Group by Store Number

# %%
sales_2015_df = sales_2015_df.groupby(by="Store Number", as_index=False)

# %% [markdown]
# Step 3 - Compute sums, means for key metrics and collapse the column indicies

# %%
sales_2015_df = sales_2015_df.agg({"Sale (Dollars)": [np.sum, np.mean],
                                   "Volume Sold (Liters)": [np.sum, np.mean],
                                   "Unit_Margin": np.mean,
                                   "Gross_Margin": [np.sum, np.mean],
                                   "Revenue_per_Liter": np.mean,
                                   "Gross_Margin_per_Liter": np.mean,
                                   "Zip Code": lambda x: x.iloc[0], # just extract once, should be the same
                                   "City": lambda x: x.iloc[0],
                                   "County Number": lambda x: x.iloc[0],
                                   "County": lambda x: x.iloc[0],
                                   "Category": lambda x: x.iloc[0],
                                   "Category Name": lambda x: x.iloc[0],
                                   "Vendor Number": lambda x: x.iloc[0],
                                   "Item Number": lambda x: x.iloc[0],
                                   "State Bottle Cost": np.mean,
                                   "State Bottle Retail": np.mean,
                                   "Bottles Sold": [np.sum, np.mean],
                                  })

sales_2015_df.columns = [' '.join(col).strip() for col in sales_2015_df.columns.values]

sales_2015_df.head(2)
# Out:
#    Store Number  Gross_Margin_per_Liter mean City <lambda>  \
# 0          2106                     5.957151   CEDAR FALLS
# 1          2113                     6.173900        GOWRIE
#
#    Sale (Dollars) sum  Sale (Dollars) mean  Revenue_per_Liter mean  \
# 0           146038.70           277.640114               17.844997
# 1             9310.22            63.334830               18.507700
#
#    Vendor Number <lambda> Zip Code <lambda>  Unit_Margin mean  \
# 0                      35             50613          5.160951
# 1                     260             50543          5.445102
#
#    Category <lambda>        ...         Gross_Margin mean  \
# 0            1062200        ...                 92.665779
# 1            1062310        ...                 21.149932
#
#    County Number <lambda>  Item Number <lambda>  \
# 0                       7                 43127
# 1                      94                 43334
#
#              Category Name <lambda>  State Bottle Cost mean  \
# 0  PUERTO RICO & VIRGIN ISLANDS RUM               10.298783
# 1                        SPICED RUM               10.870544
#
#   Volume Sold (Liters) sum  Volume Sold (Liters) mean  \
# 0                  9719.85                  18.478802
# 1                   659.85                   4.488776
#
#    State Bottle Retail mean  Bottles Sold sum  Bottles Sold mean
# 0                 15.459734             10355          19.686312
# 1                 16.315646               671           4.564626
#
# [2 rows x 22 columns]

# %%
sales_2015_df.columns
# Out:
# Index([u'Store Number', u'Gross_Margin_per_Liter mean', u'City <lambda>',
#        u'Sale (Dollars) sum', u'Sale (Dollars) mean',
#        u'Revenue_per_Liter mean', u'Vendor Number <lambda>',
#        u'Zip Code <lambda>', u'Unit_Margin mean', u'Category <lambda>',
#        u'County <lambda>', u'Gross_Margin sum', u'Gross_Margin mean',
#        u'County Number <lambda>', u'Item Number <lambda>',
#        u'Category Name <lambda>', u'State Bottle Cost mean',
#        u'Volume Sold (Liters) sum', u'Volume Sold (Liters) mean',
#        u'State Bottle Retail mean', u'Bottles Sold sum', u'Bottles Sold mean'],
#       dtype='object')

# %%
sales_2015_df['Store Number'].count()
# Out:
# 1372

# %%
sales_2015_df.shape
# Out:
# (1372, 22)

# %%
sales_2015_df = sales_2015_df.rename(index=str, columns={"Zip Code <lambda>": "Zip_Code",})

# %%
sales_2015_df.groupby(by='Zip_Code', as_index=False).agg({'Store Number': 'count'})
# Out:
#     Zip_Code  Store Number
# 0      50002             2
# 1      50003             3
# 2      50006             2
# 3      50009             9
# 4      50010            21
# 5      50014             4
# 6      50020             2
# 7      50021            12
# 8      50022             6
# 9      50023             9
# 10     50025             2
# 11     50028             2
# 12     50033             1
# 13     50035             1
# 14     50036             9
# 15     50044             1
# 16     50046             1
# 17     50047             2
# 18     50048             1
# 19     50049             2
# 20     50054             2
# 21     50056             1
# 22     50058             2
# 23     50060             1
# 24     50061             1
# 25     50069             2
# 26     50071             1
# 27     50072             1
# 28     50075             1
# 29     50076             1
# ..       ...           ...
# 379    52639             2
# 380    52641             5
# 381    52653             3
# 382    52655             5
# 383    52656             1
# 384    52722            12
# 385    52726             1
# 386    52728             1
# 387    52730             1
# 388    52732             8
# 389    52733             2
# 390    52738             2
# 391    52742             2
# 392    52747             1
# 393    52748             4
# 394    52751             1
# 395    52753             5
# 396    52761            15
# 397    52768             1
# 398    52772             3
# 399    52776             3
# 400    52777             1
# 401    52778             2
# 402    52802             8
# 403    52803             6
# 404    52804            10
# 405    52806             8
# 406    52807             9
# 407    56201             1
# 408    712-2             1
#
# [409 rows x 2 columns]

# %%
sales_by_zip_df = sales_2015_df.groupby(by='Zip_Code', as_index=False).agg({'Store Number': 'count'})
sales_by_zip_df
# Out:
#     Zip_Code  Store Number
# 0      50002             2
# 1      50003             3
# 2      50006             2
# 3      50009             9
# 4      50010            21
# 5      50014             4
# 6      50020             2
# 7      50021            12
# 8      50022             6
# 9      50023             9
# 10     50025             2
# 11     50028             2
# 12     50033             1
# 13     50035             1
# 14     50036             9
# 15     50044             1
# 16     50046             1
# 17     50047             2
# 18     50048             1
# 19     50049             2
# 20     50054             2
# 21     50056             1
# 22     50058             2
# 23     50060             1
# 24     50061             1
# 25     50069             2
# 26     50071             1
# 27     50072             1
# 28     50075             1
# 29     50076             1
# ..       ...           ...
# 379    52639             2
# 380    52641             5
# 381    52653             3
# 382    52655             5
# 383    52656             1
# 384    52722            12
# 385    52726             1
# 386    52728             1
# 387    52730             1
# 388    52732             8
# 389    52733             2
# 390    52738             2
# 391    52742             2
# 392    52747             1
# 393    52748             4
# 394    52751             1
# 395    52753             5
# 396    52761            15
# 397    52768             1
# 398    52772             3
# 399    52776             3
# 400    52777             1
# 401    52778             2
# 402    52802             8
# 403    52803             6
# 404    52804            10
# 405    52806             8
# 406    52807             9
# 407    56201             1
# 408    712-2             1
#
# [409 rows x 2 columns]

# %%
sales_by_zip_df.shape
# Out:
# (409, 2)

# %%
sales_by_zip_df.columns
# Out:
# Index([u'Zip_Code', u'Store Number'], dtype='object')

# %%
type(sales_by_zip_df)
# Out:
# pandas.core.frame.DataFrame

# %%
sales_by_zip_df['Store Number'].sum()
# Out:
# 1372

# %% [markdown]
# ##### Merging 2 dataframes of different size

# %%
# This WORKS!  Need another column - competitors = Stores in zip minus 1

# A.merge(B, left_on='lkey', right_on='rkey', how='inner')
test1_df = sales_2015_df.merge(sales_by_zip_df, left_on='Zip_Code', right_on='Zip_Code', how='inner')
test1_df
# Out:
#       Store Number_x  Gross_Margin_per_Liter mean  City <lambda>  \
# 0               2106                     5.957151    CEDAR FALLS
# 1               2572                     6.285143    CEDAR FALLS
# 2               2835                     4.842733    CEDAR FALLS
# 3               3769                     4.508190    CEDAR FALLS
# 4               3995                     6.029937    CEDAR FALLS
# 5               4119                     6.532637    CEDAR FALLS
# 6               4147                     5.051960    CEDAR FALLS
# 7               4590                     4.474135    CEDAR FALLS
# 8               4631                     4.973834    CEDAR FALLS
# 9               4723                     4.848254    CEDAR FALLS
# 10              4907                     5.598566    CEDAR FALLS
# 11              4914                     4.819141    CEDAR FALLS
# 12              4932                     5.089198    CEDAR FALLS
# 13              4958                     6.152857    CEDAR FALLS
# 14              4959                     5.768022    CEDAR FALLS
# 15              4988                     7.734273    CEDAR FALLS
# 16              2113                     6.173900         GOWRIE
# 17              5141                     6.879405         GOWRIE
# 18              2130                     5.610875       WATERLOO
# 19              2571                     5.423632       WATERLOO
# 20              2836                     4.660081       WATERLOO
# 21              4077                     7.961327       WATERLOO
# 22              4085                     6.256400       WATERLOO
# 23              4214                     6.252247       WATERLOO
# 24              4470                     4.801062       WATERLOO
# 25              4502                     6.531525       WATERLOO
# 26              4648                     8.341982       WATERLOO
# 27              4759                     4.113968       WATERLOO
# 28              4900                     7.065603       WATERLOO
# 29              4902                     7.102894       WATERLOO
# ...              ...                          ...            ...
# 1342            5026                     4.018387  NORTH ENGLISH
# 1343            5031                     6.547992        RAYMOND
# 1344            5040                     5.415482         WILTON
# 1345            5070                     4.698867         WILTON
# 1346            5044                     6.356098       CRESCENT
# 1347            5048                     5.272429          ROLFE
# 1348            5050                     5.315368       CARLISLE
# 1349            5109                     5.489211       CARLISLE
# 1350            5054                     5.848875     MANCHESTER
# 1351            5055                     3.173605        LATIMER
# 1352            5059                     5.025099       HUMESTON
# 1353            5062                     5.334874       MONTROSE
# 20         ...                            7                 37994
# 21         ...                            7                 64722
# 22         ...                            7                 52594
# 23         ...                            7                 34007
# 24         ...                            7                 43336
# 25         ...                            7                 59037
# 26         ...                            7                 49186
# 27         ...                            7                 36305
# 28         ...                            7                 36904
# 29         ...                            7                 86669
# ...        ...                          ...                   ...
# 1342       ...                           48                 58838
# 1343       ...                            7                 43116
# 1344       ...                           70                 43026
# 1345       ...                           70                 36976
# 1346       ...                           78                 48105
# 1347       ...                           76                 35318
# 1348       ...                           91                 33966
# 1349       ...                           91                 42716
# 1350       ...                           28                 67296
# 1351       ...                           35                 37338
# 1352       ...                           93                 11788
# 1353       ...                           56                 36306
# 1354       ...                           56                 43333
# 1355       ...                           57                 38176
# 1356       ...                           16                 34006
# 1357       ...                           62                 36306
# 1358       ...                           84                 88294
# 1359       ...                           98                 46506
# 1360       ...                           41                 73055
# 1361       ...                           50                 25608
# 1362       ...                           57                 19063
# 1363       ...                           79                 11788
# 1364       ...                           79                 89199
# 1365       ...                           28                 35316
# 1366       ...                           28                 65254
# 1367       ...                           78                 48105
# 1368       ...                           57                 11786
# 1369       ...                           57                 75211
# 1370       ...                           13                 19066
# 1371       ...                           91                 36447
#
#                   Category Name <lambda>  State Bottle Cost mean  \
# 0       PUERTO RICO & VIRGIN ISLANDS RUM               10.298783
# 1     MISC. IMPORTED CORDIALS & LIQUEURS                9.967925
# 2                      AMERICAN DRY GINS               10.714000
# 3                             SPICED RUM                9.897619
# 4                         VODKA FLAVORED               10.755816
# 5                         VODKA 80 PROOF               11.563077
# 6                     TENNESSEE WHISKIES                9.663605
# 7                         VODKA 80 PROOF                6.978077
# 8                        WHISKEY LIQUEUR                9.547692
# 9                      CANADIAN WHISKIES                9.580000
# 10                     CANADIAN WHISKIES                7.796042
# 11                        VODKA 80 PROOF                6.735217
# 12                        VODKA FLAVORED                7.230568
# 13                        VODKA FLAVORED                9.136853
# 14                        VODKA FLAVORED                8.855029
# 15                    AMERICAN COCKTAILS               11.378919
# 16                            SPICED RUM               10.870544
# 17    MISC. IMPORTED CORDIALS & LIQUEURS                6.803333
# 18                     IMPORTED SCHNAPPS                9.822762
# 19                        VODKA FLAVORED                9.538160
# 20                        VODKA 80 PROOF                9.293409
# 21                 IMPORTED VODKA - MISC                8.377619
# 22               AMERICAN GRAPE BRANDIES                4.657600
# 23                        IMPORTED VODKA                6.967379
# 24                            SPICED RUM                5.997308
# 25                    AMERICAN COCKTAILS                6.494571
# 26               IMPORTED GRAPE BRANDIES                8.736209
# 27                        VODKA 80 PROOF                8.473889
# 28                        VODKA 80 PROOF                6.420773
# 29                    TENNESSEE WHISKIES                6.773000
# ...                                  ...                     ...
# 1342                  AMERICAN COCKTAILS                7.138125
# 1343                        FLAVORED RUM                9.504958
# 1344                          SPICED RUM                6.725263
# 1345                      VODKA 80 PROOF                7.725771
# 1346             IMPORTED GRAPE BRANDIES                8.155909
# 1347                      VODKA 80 PROOF                9.521000
# 1348               IMPORTED VODKA - MISC                9.305207
# 1349                        FLAVORED RUM                5.328421
# 1350              MISCELLANEOUS SCHNAPPS               10.229245
# 1351                      VODKA 80 PROOF                9.740000
# 3                    14.875810              3936          12.495238
# 4                    16.140510              3242          16.540816
# 5                    17.347179               424          10.871795
# 6                    14.521769              2342          15.931973
# 7                    10.530385               284          10.923077
# 8                    14.340769               403          10.333333
# 9                    14.415556               108          12.000000
# 10                   11.705208               971          10.114583
# 11                   10.116304              1197          13.010870
# 12                   10.878523              1012          11.500000
# 13                   13.723553              1288           6.538071
# 14                   13.322659              2369          13.693642
# 15                   17.088271              3203           3.643914
# 16                   16.315646               671           4.564626
# 17                   10.261667                93           7.750000
# 18                   14.740767              7418          18.971867
# 19                   14.333380              6764          13.528000
# 20                   13.942273               171           3.886364
# 21                   12.568254              2328          18.476190
# 22                    6.987200               646          25.840000
# 23                   10.455097              4138          20.087379
# 24                    9.012308               191           7.346154
# 25                    9.747143              2194          15.671429
# 26                   13.115495              5336          29.318681
# 27                   12.713333               147           8.166667
# 28                    9.636443              2165          11.159794
# 29                   10.161250              1734          14.450000
# ...                        ...               ...                ...
# 1342                 10.709687               141           4.406250
# 1343                 14.260000               545           4.579832
# 1344                 10.090000               230          12.105263
# 1345                 11.608722               634           2.792952
# 1346                 12.269091               196           8.909091
# 1347                 14.284000               112           5.600000
# 1348                 14.000579              1723          14.239669
# 1349                  8.030000               417          21.947368
# 1350                 15.357610              3076           9.672956
# 1351                 14.650000                72          10.285714
# 1352                  9.104583               306          12.750000
# 1353                  9.145294               210          12.352941
# 1354                  3.750000                48          48.000000
# 1355                  9.721000               358          11.933333
# 1356                 12.680513               667           3.420513
# 1357                 14.333684               129           6.789474
# 1358                 10.661905               177           8.428571
# 1359                 10.412143               278           9.928571
# 1360                 15.588750               163           6.791667
# 1361                 12.223889               325           6.018519
# 1362                  9.934286               957           3.255102
# 1363                 13.330952               269           6.404762
# 1364                 11.541765               120           7.058824
# 1365                 12.592308               184          14.153846
# 1366                 10.803333                23           3.833333
# 1367                 14.952000                42           8.400000
# 1368                 14.816000                85           5.666667
# 1369                 15.000000                 6           6.000000
# 1370                 11.373333                12           4.000000
# 1371                 12.712500               228          57.000000
#
#       Store Number_y
# 0                 16
# 1                 16
# 2                 16
# 3                 16
# 4                 16
# 5                 16
# 6                 16
# 7                 16
# 8                 16
# 9                 16
# 10                16
# 11                16
# 12                16
# 13                16
# 14                16
# 15                16
# 16                 2
# 17                 2
# 18                16
# 19                16
# 20                16
# 21                16
# 22                16
# 23                16
# 24                16
# 25                16
# 26                16
# 27                16
# 28                16
# 29                16
# ...              ...
# 1342               1
# 1343               1
# 1344               2
# 1345               2
# 1346               1
# 1347               1
# 1348               2
# 1349               2
# 1350               1
# 1351               1
# 1352               1
# 1353               2
# 1354               2
# 1355               1
# 1356               1
# 1357               1
# 1358               1
# 1359               1
# 1360               1
# 1361               1
# 1362               1
# 1363               2
# 1364               2
# 1365               1
# 1366               1
# 1367               1
# 1368               1
# 1369               1
# 1370               1
# 1371               1
#
# [1372 rows x 23 columns]

# %%
test1_df.shape
# Out:
# (1372, 23)

# %% [markdown]
# ### Groupbys and Pivot Tables

# %%
# old_names = ['$a', '$b', '$c', '$d', '$e'] 
# new_names = ['a', 'b', 'c', 'd', 'e']
# df.rename(columns=dict(zip(old_names, new_names)), inplace=True)

# %%
test1_df.columns
# Out:
# Index([u'Store Number_x', u'Gross_Margin_per_Liter mean', u'City <lambda>',
#        u'Sale (Dollars) sum', u'Sale (Dollars) mean',
#        u'Revenue_per_Liter mean', u'Vendor Number <lambda>', u'Zip_Code',
#        u'Unit_Margin mean', u'Category <lambda>', u'County <lambda>',
#        u'Gross_Margin sum', u'Gross_Margin mean', u'County Number <lambda>',
#        u'Item Number <lambda>', u'Category Name <lambda>',
#        u'State Bottle Cost mean', u'Volume Sold (Liters) sum',
#        u'Volume Sold (Liters) mean', u'State Bottle Retail mean',
#        u'Bottles Sold sum', u'Bottles Sold mean', u'Store Number_y'],
#       dtype='object')

# %%
test1_df.rename(columns=lambda x: x.lstrip(), inplace=True)
test1_df.head(2)
# Out:
#    Store Number_x  Gross_Margin_per_Liter mean City <lambda>  \
# 0            2106                     5.957151   CEDAR FALLS
# 1            2572                     6.285143   CEDAR FALLS
#
#    Sale (Dollars) sum  Sale (Dollars) mean  Revenue_per_Liter mean  \
# 0           146038.70           277.640114               17.844997
# 1            98831.43            75.965742               18.800332
#
#    Vendor Number <lambda> Zip_Code  Unit_Margin mean  Category <lambda>  \
# 0                      35    50613          5.160951            1062200
# 1                     410    50613          5.007233            1082900
#
#         ...       County Number <lambda>  Item Number <lambda>  \
# 0       ...                            7                 43127
# 1       ...                            7                 64736
#
#                Category Name <lambda>  State Bottle Cost mean  \
# 0    PUERTO RICO & VIRGIN ISLANDS RUM               10.298783
# 1  MISC. IMPORTED CORDIALS & LIQUEURS                9.967925
#
#    Volume Sold (Liters) sum Volume Sold (Liters) mean  \
# 0                   9719.85                 18.478802
# 1                   6080.74                  4.673897
#
#    State Bottle Retail mean  Bottles Sold sum  Bottles Sold mean  \
# 0                 15.459734             10355          19.686312
# 1                 14.975158              6549           5.033820
#
#    Store Number_y
# 0              16
# 1              16
#
# [2 rows x 23 columns]

# %%
test1_df.columns
# Out:
# Index([u'Store Number_x', u'Gross_Margin_per_Liter mean', u'City <lambda>',
#        u'Sale (Dollars) sum', u'Sale (Dollars) mean',
#        u'Revenue_per_Liter mean', u'Vendor Number <lambda>', u'Zip_Code',
#        u'Unit_Margin mean', u'Category <lambda>', u'County <lambda>',
#        u'Gross_Margin sum', u'Gross_Margin mean', u'County Number <lambda>',
#        u'Item Number <lambda>', u'Category Name <lambda>',
#        u'State Bottle Cost mean', u'Volume Sold (Liters) sum',
#        u'Volume Sold (Liters) mean', u'State Bottle Retail mean',
#        u'Bottles Sold sum', u'Bottles Sold mean', u'Store Number_y'],
#       dtype='object')

# %%
test1_df.columns = test1_df.columns.str.replace(' <lambda>', '')
test1_df.columns
# Out:
# Index([u'Store Number_x', u'Gross_Margin_per_Liter mean', u'City',
#        u'Sale (Dollars) sum', u'Sale (Dollars) mean',
#        u'Revenue_per_Liter mean', u'Vendor Number', u'Zip_Code',
#        u'Unit_Margin mean', u'Category', u'County', u'Gross_Margin sum',
#        u'Gross_Margin mean', u'County Number', u'Item Number',
#        u'Category Name', u'State Bottle Cost mean',
#        u'Volume Sold (Liters) sum', u'Volume Sold (Liters) mean',
#        u'State Bottle Retail mean', u'Bottles Sold sum', u'Bottles Sold mean',
#        u'Store Number_y'],
#       dtype='object')

# %%
test1_df.head(2)
# Out:
#    Store Number_x  Gross_Margin_per_Liter mean         City  \
# 0            2106                     5.957151  CEDAR FALLS
# 1            2572                     6.285143  CEDAR FALLS
#
#    Sale (Dollars) sum  Sale (Dollars) mean  Revenue_per_Liter mean  \
# 0           146038.70           277.640114               17.844997
# 1            98831.43            75.965742               18.800332
#
#    Vendor Number Zip_Code  Unit_Margin mean  Category       ...        \
# 0             35    50613          5.160951   1062200       ...
# 1            410    50613          5.007233   1082900       ...
#
#   County Number  Item Number                       Category Name  \
# 0             7        43127    PUERTO RICO & VIRGIN ISLANDS RUM
# 1             7        64736  MISC. IMPORTED CORDIALS & LIQUEURS
#
#    State Bottle Cost mean  Volume Sold (Liters) sum Volume Sold (Liters) mean  \
# 0               10.298783                   9719.85                 18.478802
# 1                9.967925                   6080.74                  4.673897
#
#    State Bottle Retail mean  Bottles Sold sum  Bottles Sold mean  \
# 0                 15.459734             10355          19.686312
# 1                 14.975158              6549           5.033820
#
#    Store Number_y
# 0              16
# 1              16
#
# [2 rows x 23 columns]

# %%
test1_df = test1_df.rename(index=str, columns={"Store Number_y": "Competitors_per_Zip",})
test1_df.head(2)
# Out:
#    Store Number_x  Gross_Margin_per_Liter mean         City  \
# 0            2106                     5.957151  CEDAR FALLS
# 1            2572                     6.285143  CEDAR FALLS
#
#    Sale (Dollars) sum  Sale (Dollars) mean  Revenue_per_Liter mean  \
# 0           146038.70           277.640114               17.844997
# 1            98831.43            75.965742               18.800332
#
#    Vendor Number Zip_Code  Unit_Margin mean  Category         ...           \
# 0             35    50613          5.160951   1062200         ...
# 1            410    50613          5.007233   1082900         ...
#
#   County Number  Item Number                       Category Name  \
# 0             7        43127    PUERTO RICO & VIRGIN ISLANDS RUM
# 1             7        64736  MISC. IMPORTED CORDIALS & LIQUEURS
#
#    State Bottle Cost mean  Volume Sold (Liters) sum Volume Sold (Liters) mean  \
# 0               10.298783                   9719.85                 18.478802
# 1                9.967925                   6080.74                  4.673897
#
#    State Bottle Retail mean  Bottles Sold sum  Bottles Sold mean  \
# 0                 15.459734             10355          19.686312
# 1                 14.975158              6549           5.033820
#
#    Competitors_per_Zip
# 0                   16
# 1                   16
#
# [2 rows x 23 columns]

# %%
test1_df['Competitors_per_Zip'] = (test1_df['Competitors_per_Zip'] - 1)

# %%
test1_df.head(2)
# Out:
#    Store Number_x  Gross_Margin_per_Liter mean         City  \
# 0            2106                     5.957151  CEDAR FALLS
# 1            2572                     6.285143  CEDAR FALLS
#
#    Sale (Dollars) sum  Sale (Dollars) mean  Revenue_per_Liter mean  \
# 0           146038.70           277.640114               17.844997
# 1            98831.43            75.965742               18.800332
#
#    Vendor Number Zip_Code  Unit_Margin mean  Category         ...           \
# 0             35    50613          5.160951   1062200         ...
# 1            410    50613          5.007233   1082900         ...
#
#   County Number  Item Number                       Category Name  \
# 0             7        43127    PUERTO RICO & VIRGIN ISLANDS RUM
# 1             7        64736  MISC. IMPORTED CORDIALS & LIQUEURS
#
#    State Bottle Cost mean  Volume Sold (Liters) sum Volume Sold (Liters) mean  \
# 0               10.298783                   9719.85                 18.478802
# 1                9.967925                   6080.74                  4.673897
#
#    State Bottle Retail mean  Bottles Sold sum  Bottles Sold mean  \
# 0                 15.459734             10355          19.686312
# 1                 14.975158              6549           5.033820
#
#    Competitors_per_Zip
# 0                   15
# 1                   15
#
# [2 rows x 23 columns]

# %%
test1_df.columns
# Out:
# Index([u'Store Number_x', u'Gross_Margin_per_Liter mean', u'City',
#        u'Sale (Dollars) sum', u'Sale (Dollars) mean',
#        u'Revenue_per_Liter mean', u'Vendor Number', u'Zip_Code',
#        u'Unit_Margin mean', u'Category', u'County', u'Gross_Margin sum',
#        u'Gross_Margin mean', u'County Number', u'Item Number',
#        u'Category Name', u'State Bottle Cost mean',
#        u'Volume Sold (Liters) sum', u'Volume Sold (Liters) mean',
#        u'State Bottle Retail mean', u'Bottles Sold sum', u'Bottles Sold mean',
#        u'Competitors_per_Zip'],
#       dtype='object')

# %% [markdown]
# ##### This allows you display all of the columns

# %%
pd.set_option("display.max_columns",999)

# %%
test1_df.head(2)
# Out:
#    Store Number_x  Gross_Margin_per_Liter mean         City  \
# 0            2106                     5.957151  CEDAR FALLS
# 1            2572                     6.285143  CEDAR FALLS
#
#    Sale (Dollars) sum  Sale (Dollars) mean  Revenue_per_Liter mean  \
# 0           146038.70           277.640114               17.844997
# 1            98831.43            75.965742               18.800332
#
#    Vendor Number Zip_Code  Unit_Margin mean  Category      County  \
# 0             35    50613          5.160951   1062200  Black Hawk
# 1            410    50613          5.007233   1082900  Black Hawk
#
#    Gross_Margin sum  Gross_Margin mean  County Number  Item Number  \
# 0          48742.20          92.665779              7        43127
# 1          33027.37          25.386141              7        64736
#
#                         Category Name  State Bottle Cost mean  \
# 0    PUERTO RICO & VIRGIN ISLANDS RUM               10.298783
# 1  MISC. IMPORTED CORDIALS & LIQUEURS                9.967925
#
#    Volume Sold (Liters) sum  Volume Sold (Liters) mean  \
# 0                   9719.85                  18.478802
# 1                   6080.74                   4.673897
#
#    State Bottle Retail mean  Bottles Sold sum  Bottles Sold mean  \
# 0                 15.459734             10355          19.686312
# 1                 14.975158              6549           5.033820
#
#    Competitors_per_Zip
# 0                   15
# 1                   15

# %% [markdown]
# ### Groupby and Pivot Tables

# %%
# Need to clean up column names

# %%
zip_sum1_df = test1_df.groupby(by='Zip_Code', 
                               as_index=False).agg({'Volume Sold (Liters) sum': np.sum, #zip vols
                                                    'Volume Sold (Liters) mean': np.mean, #avg store vol
                                                    'Bottles Sold sum': np.sum, #total bottles for zip
                                                    'Bottles Sold mean': np.mean, #bottles/store
        
                                                    'Sale (Dollars) sum': np.sum, #gross sales for zip
                                                    'Sale (Dollars) mean': np.mean, #sales per store
                                                    'State Bottle Retail mean': np.mean, #avg sales price
                                                    'Revenue_per_Liter mean': np.mean, #avg rev per liter
                                                                   
                                                    'Gross_Margin sum': np.sum, #Total Gross Margin $s in zip
                                                    'Gross_Margin mean': np.mean, #Average GM per store
# 404                 12.397127           375470.88                  24901.50
# 405                 14.000380           181948.52                  13983.10
# 406                 14.785964           596547.82                  39654.35
# 407                 16.866500             4086.72                    243.00
# 408                 16.267459            15185.99                   1021.40
#
#      Gross_Margin mean
# 0            43.327853
# 1            45.606403
# 2            45.921813
# 3            54.957015
# 4            46.394115
# 5            36.897423
# 6            29.225108
# 7            62.020481
# 8            40.544068
# 9            28.872319
# 10           26.774648
# 11           30.061341
# 12           25.490333
# 13           10.306997
# 14           42.951151
# 15           40.668000
# 16           12.927568
# 17           53.431740
# 18           48.363214
# 19           42.438365
# 20           30.651668
# 21           46.110000
# 22           29.084912
# 23           26.412477
# 24          184.950000
# 25           32.435510
# 26           55.456364
# 27           29.794687
# 28           27.663816
# 29           50.529474
# ..                 ...
# 379          45.909706
# 380          39.335705
# 381          24.940022
# 382          39.620875
# 383          49.565915
# 384          40.455749
# 385           8.325418
# 386          50.950370
# 387          35.137522
# 388          41.184549
# 389          38.861668
# 390          48.837288
# 391          83.451107
# 392          12.255590
# 393          26.736331
# 394          19.281837
# 395          70.796314
# 396          26.715408
# 397          21.569118
# 398          31.438948
# 399          28.058033
# 400          15.770000
# 401          23.652654
# 402          29.781484
# 403          49.867448
# 404          46.741333
# 405          39.587902
# 406          69.450184
# 407          68.139000
# 408          27.394486
#
# [409 rows x 13 columns]

# %%
zip_economics = zip_sum1_df.describe()
zip_economics
# Out:
#        Unit_Margin mean  Volume Sold (Liters) mean  \
# count        409.000000                 409.000000
# mean           4.478848                   8.444306
# std            0.847453                   3.865844
# min            1.515000                   1.283333
# 25%            4.076296                   6.189922
# 50%            4.496012                   7.877163
# 75%            4.866614                  10.015967
# max           13.850294                  42.750000
#
#        Gross_Margin_per_Liter mean  Bottles Sold sum  Gross_Margin sum  \
# count                   409.000000        409.000000        409.000000
# mean                      5.475616       5312.616137      23285.925697
# std                       1.078871      10692.295033      48869.945345
# min                       3.173605          6.000000         30.000000
# 25%                       4.947954        362.000000       1362.780000
# 50%                       5.389800        994.000000       3959.950000
# 75%                       5.887173       5054.000000      21699.110000
# max                      18.435410      75492.000000     356316.110000
#
#        Sale (Dollars) mean  Bottles Sold mean  Revenue_per_Liter mean  \
# count           409.000000         409.000000              409.000000
# mean            111.474184           9.845367               16.391895
# std              54.777782           5.116654                3.240266
# min              24.911009           2.288184                9.474014
# 25%              79.899147           6.849671               14.806887
# 50%             104.799590           9.169748               16.131523
# 75%             129.440076          11.490196               17.630704
# max             554.370000          57.000000               55.282316
#
#        State Bottle Retail mean  Sale (Dollars) sum  Volume Sold (Liters) sum  \
# count                409.000000        4.090000e+02                409.000000
# mean                  13.398114        6.962998e+04               4851.157335
# std                    2.543043        1.462681e+05               9605.821665
# min                    4.540000        9.000000e+01                  4.500000
# 25%                   12.153020        4.086720e+03                326.360000
# 50%                   13.462229        1.182521e+04                964.550000
# 75%                   14.558562        6.499227e+04               4932.290000
# max                   41.530760        1.068201e+06              69711.670000
#
#        Gross_Margin mean
# count         409.000000
# mean           37.312706
# std            18.340656
# min             8.325418
# 25%            26.774648
# 50%            34.990641
# 75%            43.346382
# max           184.950000
